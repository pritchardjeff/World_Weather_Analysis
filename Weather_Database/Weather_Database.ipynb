# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=397f8c45903625e0b3aad56880da28b5

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | vila velha
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | klaksvik
# Processing Record 5 of Set 1 | imeni poliny osipenko
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | mouzakion
# City not found. Skipping...
# Processing Record 10 of Set 1 | zambezi
# Processing Record 11 of Set 1 | belen
# Processing Record 12 of Set 1 | waingapu
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | oktyabrskoye
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | winnemucca
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | biak
# Processing Record 32 of Set 1 | bellavista
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | puerto colombia
# Processing Record 36 of Set 1 | ogulin
# Processing Record 37 of Set 1 | huilong
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | morgantown
# Processing Record 40 of Set 1 | pozo colorado
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | pinega
# Processing Record 43 of Set 1 | deputatskiy
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | rawson
# Processing Record 46 of Set 1 | oktyabrskiy
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | labuhan
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | izhma
# Processing Record 1 of Set 2 | shatsk
# Processing Record 2 of Set 2 | la palma
# Processing Record 3 of Set 2 | tukrah
# Processing Record 4 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | udachnyy
# Processing Record 8 of Set 2 | quatre cocos
# Processing Record 9 of Set 2 | okandja
# City not found. Skipping...
# Processing Record 10 of Set 2 | flinders
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | kilrush
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | lewiston
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | la sarre
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 2 | puerto rondon
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | saint-joseph
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | mount isa
# Processing Record 28 of Set 2 | wanning
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | opelousas
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | zyryanka
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | yelan-kolenovskiy
# Processing Record 40 of Set 2 | sorland
# Processing Record 41 of Set 2 | trinidad
# Processing Record 42 of Set 2 | axim
# Processing Record 43 of Set 2 | caucasia
# Processing Record 44 of Set 2 | rimouski
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | khovu-aksy
# Processing Record 1 of Set 3 | distraccion
# Processing Record 2 of Set 3 | elizabeth city
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | sorong
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | sao miguel
# Processing Record 14 of Set 3 | ballina
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | burriana
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 3 | nemuro
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | podosinovets
# Processing Record 25 of Set 3 | manado
# Processing Record 26 of Set 3 | aakirkeby
# City not found. Skipping...
# Processing Record 27 of Set 3 | abu zabad
# Processing Record 28 of Set 3 | qiyang
# Processing Record 29 of Set 3 | kinwat
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | revda
# Processing Record 34 of Set 3 | sao jose da coroa grande
# Processing Record 35 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | macau
# Processing Record 38 of Set 3 | grindavik
# Processing Record 39 of Set 3 | tuy hoa
# Processing Record 40 of Set 3 | atambua
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | winnipeg
# Processing Record 43 of Set 3 | pisco
# Processing Record 44 of Set 3 | hithadhoo
# Processing Record 45 of Set 3 | taybad
# Processing Record 46 of Set 3 | benalla
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | olafsvik
# Processing Record 50 of Set 3 | pampa
# Processing Record 1 of Set 4 | hofn
# Processing Record 2 of Set 4 | zhigansk
# Processing Record 3 of Set 4 | vammala
# Processing Record 4 of Set 4 | cedar city
# Processing Record 5 of Set 4 | germersheim
# Processing Record 6 of Set 4 | nanga eboko
# Processing Record 7 of Set 4 | airai
# Processing Record 8 of Set 4 | estelle
# Processing Record 9 of Set 4 | krasnoselkup
# Processing Record 10 of Set 4 | kihei
# Processing Record 11 of Set 4 | san francisco
# Processing Record 12 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | maceio
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | solnechnyy
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | fairbanks
# Processing Record 22 of Set 4 | raton
# Processing Record 23 of Set 4 | campo verde
# Processing Record 24 of Set 4 | nago
# Processing Record 25 of Set 4 | kathmandu
# Processing Record 26 of Set 4 | santa cruz de la palma
# Processing Record 27 of Set 4 | vestmannaeyjar
# Processing Record 28 of Set 4 | haines junction
# Processing Record 29 of Set 4 | halifax
# Processing Record 30 of Set 4 | jalu
# Processing Record 31 of Set 4 | plettenberg bay
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | mangrol
# Processing Record 35 of Set 4 | shingu
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | tulun
# Processing Record 38 of Set 4 | zihuatanejo
# Processing Record 39 of Set 4 | ohara
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | adrar
# Processing Record 42 of Set 4 | cururupu
# Processing Record 43 of Set 4 | tahe
# Processing Record 44 of Set 4 | conde
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | preobrazheniye
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | noumea
# Processing Record 49 of Set 4 | smithers
# Processing Record 50 of Set 4 | souillac
# Processing Record 1 of Set 5 | edd
# Processing Record 2 of Set 5 | batagay
# Processing Record 3 of Set 5 | magistralnyy
# Processing Record 4 of Set 5 | angoche
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | umuarama
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | manjacaze
# Processing Record 9 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 5 | asau
# Processing Record 11 of Set 5 | khorixas
# Processing Record 12 of Set 5 | honiara
# Processing Record 13 of Set 5 | villa carlos paz
# Processing Record 14 of Set 5 | hokitika
# Processing Record 15 of Set 5 | keetmanshoop
# Processing Record 16 of Set 5 | lazaro cardenas
# Processing Record 17 of Set 5 | warmbad
# Processing Record 18 of Set 5 | dhidhdhoo
# Processing Record 19 of Set 5 | muncar
# Processing Record 20 of Set 5 | naruto
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | acajutla
# Processing Record 23 of Set 5 | tornio
# Processing Record 24 of Set 5 | pacific grove
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | lagoa
# Processing Record 27 of Set 5 | srednekolymsk
# Processing Record 28 of Set 5 | nouadhibou
# Processing Record 29 of Set 5 | tual
# Processing Record 30 of Set 5 | bathsheba
# Processing Record 31 of Set 5 | taltal
# Processing Record 32 of Set 5 | port blair
# Processing Record 33 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 5 | paducah
# Processing Record 35 of Set 5 | vardo
# Processing Record 36 of Set 5 | kurilsk
# Processing Record 37 of Set 5 | maua
# Processing Record 38 of Set 5 | kumluca
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | port macquarie
# Processing Record 41 of Set 5 | port-cartier
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | dafeng
# Processing Record 44 of Set 5 | kavieng
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | constitucion
# Processing Record 47 of Set 5 | puerto baquerizo moreno
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 50 of Set 5 | padang
# Processing Record 1 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 6 | doljo
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | yulara
# Processing Record 5 of Set 6 | brokopondo
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | hay river
# Processing Record 8 of Set 6 | bagli
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | malakal
# Processing Record 11 of Set 6 | maneromango
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | bakchar
# Processing Record 14 of Set 6 | esperance
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | poplar bluff
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | bac can
# City not found. Skipping...
# Processing Record 19 of Set 6 | kupang
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | ilhabela
# Processing Record 22 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 23 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 6 | gulbarga
# Processing Record 25 of Set 6 | yerbogachen
# Processing Record 26 of Set 6 | moron
# Processing Record 27 of Set 6 | shcholkine
# City not found. Skipping...
# Processing Record 28 of Set 6 | carauari
# Processing Record 29 of Set 6 | esmeraldas
# Processing Record 30 of Set 6 | gra liyia
# Processing Record 31 of Set 6 | koszeg
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | anenecuilco
# Processing Record 34 of Set 6 | gat
# Processing Record 35 of Set 6 | bonavista
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | goderich
# Processing Record 38 of Set 6 | ambilobe
# Processing Record 39 of Set 6 | dali
# Processing Record 40 of Set 6 | sitborice
# Processing Record 41 of Set 6 | tessalit
# Processing Record 42 of Set 6 | villa bruzual
# Processing Record 43 of Set 6 | puerto escondido
# Processing Record 44 of Set 6 | cockburn town
# Processing Record 45 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 6 | dongsheng
# Processing Record 47 of Set 6 | meadow lake
# Processing Record 48 of Set 6 | saint-francois
# Processing Record 49 of Set 6 | takoradi
# Processing Record 50 of Set 6 | chuy
# Processing Record 1 of Set 7 | juneau
# Processing Record 2 of Set 7 | laguna
# Processing Record 3 of Set 7 | north myrtle beach
# Processing Record 4 of Set 7 | innisfail
# Processing Record 5 of Set 7 | mairi
# Processing Record 6 of Set 7 | bowen
# Processing Record 7 of Set 7 | sainte-thecle
# Processing Record 8 of Set 7 | caronport
# Processing Record 9 of Set 7 | opuwo
# Processing Record 10 of Set 7 | xuddur
# Processing Record 11 of Set 7 | trairi
# Processing Record 12 of Set 7 | kasane
# Processing Record 13 of Set 7 | kabompo
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | salinopolis
# Processing Record 16 of Set 7 | dinan
# Processing Record 17 of Set 7 | bay roberts
# Processing Record 18 of Set 7 | vagur
# Processing Record 19 of Set 7 | karratha
# Processing Record 20 of Set 7 | chara
# Processing Record 21 of Set 7 | byron bay
# Processing Record 22 of Set 7 | sidi bu zayd
# City not found. Skipping...
# Processing Record 23 of Set 7 | fare
# Processing Record 24 of Set 7 | vanavara
# Processing Record 25 of Set 7 | tabuk
# Processing Record 26 of Set 7 | korla
# Processing Record 27 of Set 7 | opunake
# Processing Record 28 of Set 7 | dong xoai
# Processing Record 29 of Set 7 | berekum
# Processing Record 30 of Set 7 | antofagasta
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | thies
# Processing Record 33 of Set 7 | omboue
# Processing Record 34 of Set 7 | fort-shevchenko
# Processing Record 35 of Set 7 | wageningen
# Processing Record 36 of Set 7 | macusani
# Processing Record 37 of Set 7 | torquay
# Processing Record 38 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 7 | ibra
# Processing Record 40 of Set 7 | sambava
# Processing Record 41 of Set 7 | yumen
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | yakeshi
# Processing Record 44 of Set 7 | college
# Processing Record 45 of Set 7 | launceston
# Processing Record 46 of Set 7 | puerto del rosario
# Processing Record 47 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 7 | votice
# Processing Record 49 of Set 7 | vaitape
# Processing Record 50 of Set 7 | teguise
# Processing Record 1 of Set 8 | namibe
# Processing Record 2 of Set 8 | sabang
# Processing Record 3 of Set 8 | roald
# Processing Record 4 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 8 | imbituba
# Processing Record 6 of Set 8 | andilamena
# Processing Record 7 of Set 8 | phoenixville
# Processing Record 8 of Set 8 | liepaja
# Processing Record 9 of Set 8 | parainen
# Processing Record 10 of Set 8 | calama
# Processing Record 11 of Set 8 | marshall
# Processing Record 12 of Set 8 | artigas
# Processing Record 13 of Set 8 | batagay-alyta
# Processing Record 14 of Set 8 | pimentel
# Processing Record 15 of Set 8 | cap malheureux
# Processing Record 16 of Set 8 | magadi
# Processing Record 17 of Set 8 | marsh harbour
# Processing Record 18 of Set 8 | thunder bay
# Processing Record 19 of Set 8 | longyearbyen
# Processing Record 20 of Set 8 | vostok
# Processing Record 21 of Set 8 | inhambane
# Processing Record 22 of Set 8 | nykobing
# City not found. Skipping...
# Processing Record 23 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 8 | ankazoabo
# Processing Record 25 of Set 8 | puteyets
# Processing Record 26 of Set 8 | sai buri
# Processing Record 27 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 8 | pietroasele
# Processing Record 29 of Set 8 | merauke
# Processing Record 30 of Set 8 | dingle
# Processing Record 31 of Set 8 | issenye
# Processing Record 32 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 33 of Set 8 | sao filipe
# Processing Record 34 of Set 8 | dukat
# Processing Record 35 of Set 8 | misratah
# Processing Record 36 of Set 8 | nemours
# Processing Record 37 of Set 8 | saint-michel-des-saints
# Processing Record 38 of Set 8 | presidencia roque saenz pena
# Processing Record 39 of Set 8 | leshukonskoye
# Processing Record 40 of Set 8 | lyantonde
# Processing Record 41 of Set 8 | harqalah
# Processing Record 42 of Set 8 | zemio
# Processing Record 43 of Set 8 | half moon bay
# Processing Record 44 of Set 8 | kongwa
# Processing Record 45 of Set 8 | matara
# Processing Record 46 of Set 8 | wajid
# Processing Record 47 of Set 8 | niquelandia
# Processing Record 48 of Set 8 | lensk
# Processing Record 49 of Set 8 | koslan
# Processing Record 50 of Set 8 | kaputa
# Processing Record 1 of Set 9 | hasaki
# Processing Record 2 of Set 9 | high level
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | saint-ambroise
# Processing Record 5 of Set 9 | provost
# Processing Record 6 of Set 9 | san quintin
# Processing Record 7 of Set 9 | hervey bay
# Processing Record 8 of Set 9 | gap
# Processing Record 9 of Set 9 | zonguldak
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | cooma
# Processing Record 12 of Set 9 | rila
# Processing Record 13 of Set 9 | scottsbluff
# Processing Record 14 of Set 9 | camacha
# Processing Record 15 of Set 9 | pasighat
# Processing Record 16 of Set 9 | kandete
# Processing Record 17 of Set 9 | povenets
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | ihosy
# Processing Record 20 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | manaus
# Processing Record 22 of Set 9 | along
# Processing Record 23 of Set 9 | sibolga
# Processing Record 24 of Set 9 | aykhal
# Processing Record 25 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 9 | shestakovo
# Processing Record 27 of Set 9 | vila
# Processing Record 28 of Set 9 | iralaya
# Processing Record 29 of Set 9 | sioux lookout
# Processing Record 30 of Set 9 | mastic beach
# Processing Record 31 of Set 9 | grand island
# Processing Record 32 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 33 of Set 9 | hamilton
# Processing Record 34 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 9 | mabaruma
# Processing Record 36 of Set 9 | vidim
# Processing Record 37 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 9 | marsabit
# Processing Record 41 of Set 9 | bulgan
# Processing Record 42 of Set 9 | taoudenni
# Processing Record 43 of Set 9 | maldonado
# Processing Record 44 of Set 9 | dunedin
# Processing Record 45 of Set 9 | port hardy
# Processing Record 46 of Set 9 | catabola
# Processing Record 47 of Set 9 | saint-georges
# Processing Record 48 of Set 9 | piacabucu
# Processing Record 49 of Set 9 | novyy urengoy
# Processing Record 50 of Set 9 | zhangye
# Processing Record 1 of Set 10 | palmer
# Processing Record 2 of Set 10 | mapiripan
# Processing Record 3 of Set 10 | gravdal
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | rocha
# Processing Record 6 of Set 10 | colares
# Processing Record 7 of Set 10 | narathiwat
# Processing Record 8 of Set 10 | naze
# Processing Record 9 of Set 10 | shenzhen
# Processing Record 10 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 11 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 12 of Set 10 | avera
# Processing Record 13 of Set 10 | kristiansund
# Processing Record 14 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 10 | susanville
# Processing Record 16 of Set 10 | prince rupert
# Processing Record 17 of Set 10 | kurchatov
# Processing Record 18 of Set 10 | kenora
# Processing Record 19 of Set 10 | brockville
# Processing Record 20 of Set 10 | marawi
# Processing Record 21 of Set 10 | burnie
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | labuan
# Processing Record 24 of Set 10 | rio gallegos
# Processing Record 25 of Set 10 | lethbridge
# Processing Record 26 of Set 10 | ponta delgada
# Processing Record 27 of Set 10 | alberton
# Processing Record 28 of Set 10 | berat
# Processing Record 29 of Set 10 | tefe
# Processing Record 30 of Set 10 | tateyama
# Processing Record 31 of Set 10 | cayenne
# Processing Record 32 of Set 10 | pangai
# Processing Record 33 of Set 10 | cherskiy
# Processing Record 34 of Set 10 | luang prabang
# Processing Record 35 of Set 10 | ostrovnoy
# Processing Record 36 of Set 10 | scarborough
# Processing Record 37 of Set 10 | jumla
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | christchurch
# Processing Record 40 of Set 10 | san pedro
# Processing Record 41 of Set 10 | mawlaik
# Processing Record 42 of Set 10 | ayolas
# Processing Record 43 of Set 10 | broken hill
# Processing Record 44 of Set 10 | solenzo
# Processing Record 45 of Set 10 | sturgis
# Processing Record 46 of Set 10 | el dorado
# Processing Record 47 of Set 10 | zgierz
# Processing Record 48 of Set 10 | patiala
# Processing Record 49 of Set 10 | shush
# Processing Record 50 of Set 10 | amuntai
# Processing Record 1 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 2 of Set 11 | kibala
# Processing Record 3 of Set 11 | touros
# Processing Record 4 of Set 11 | punto fijo
# Processing Record 5 of Set 11 | kahului
# Processing Record 6 of Set 11 | santiago del estero
# Processing Record 7 of Set 11 | anori
# Processing Record 8 of Set 11 | potsdam
# Processing Record 9 of Set 11 | oros
# Processing Record 10 of Set 11 | nha trang
# Processing Record 11 of Set 11 | belaya gora
# Processing Record 12 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 11 | te karaka
# Processing Record 14 of Set 11 | monduli
# Processing Record 15 of Set 11 | zhanakorgan
# Processing Record 16 of Set 11 | poya
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | bucerias
# Processing Record 19 of Set 11 | straumen
# Processing Record 20 of Set 11 | southbridge
# Processing Record 21 of Set 11 | xinzhou
# Processing Record 22 of Set 11 | guerrero negro
# Processing Record 23 of Set 11 | vrangel
# Processing Record 24 of Set 11 | oksfjord
# Processing Record 25 of Set 11 | asilah
# Processing Record 26 of Set 11 | muros
# Processing Record 27 of Set 11 | fomboni
# Processing Record 28 of Set 11 | hanna
# Processing Record 29 of Set 11 | port moresby
# Processing Record 30 of Set 11 | ust-nera
# Processing Record 31 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 11 | the valley
# Processing Record 33 of Set 11 | shihezi
# Processing Record 34 of Set 11 | sulangan
# Processing Record 35 of Set 11 | yaan
# Processing Record 36 of Set 11 | poum
# Processing Record 37 of Set 11 | platanos
# Processing Record 38 of Set 11 | isangel
# Processing Record 39 of Set 11 | zyryanskoye
# Processing Record 40 of Set 11 | grand-lahou
# Processing Record 41 of Set 11 | dawson creek
# Processing Record 42 of Set 11 | zenzeli
# Processing Record 43 of Set 11 | volchikha
# Processing Record 44 of Set 11 | abay
# Processing Record 45 of Set 11 | mchinji
# Processing Record 46 of Set 11 | sumbe
# Processing Record 47 of Set 11 | leninskoye
# Processing Record 48 of Set 11 | maues
# Processing Record 49 of Set 11 | tocantinopolis
# City not found. Skipping...
# Processing Record 50 of Set 11 | hualmay
# Processing Record 1 of Set 12 | rudnya
# Processing Record 2 of Set 12 | carutapera
# Processing Record 3 of Set 12 | eyl
# Processing Record 4 of Set 12 | harboore
# Processing Record 5 of Set 12 | passo de camaragibe
# Processing Record 6 of Set 12 | westport
# Processing Record 7 of Set 12 | alugan
# Processing Record 8 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 9 of Set 12 | terney
# Processing Record 10 of Set 12 | dudinka
# Processing Record 11 of Set 12 | iquique
# Processing Record 12 of Set 12 | hami
# Processing Record 13 of Set 12 | brae
# Processing Record 14 of Set 12 | san juan
# Processing Record 15 of Set 12 | cuiluan
# Processing Record 16 of Set 12 | navirai
# Processing Record 17 of Set 12 | mehamn
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | boffa
# Processing Record 20 of Set 12 | maragogi
# Processing Record 21 of Set 12 | san patricio
# Processing Record 22 of Set 12 | rorvik
# Processing Record 23 of Set 12 | harjavalta
# Processing Record 24 of Set 12 | ler
# Processing Record 25 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 12 | berlevag
# Processing Record 27 of Set 12 | lata
# Processing Record 28 of Set 12 | semnan
# Processing Record 29 of Set 12 | agirish
# Processing Record 30 of Set 12 | muisne
# Processing Record 31 of Set 12 | baruun-urt
# Processing Record 32 of Set 12 | mindif
# Processing Record 33 of Set 12 | cavalcante
# Processing Record 34 of Set 12 | nagapattinam
# Processing Record 35 of Set 12 | gorontalo
# Processing Record 36 of Set 12 | zboriste
# Processing Record 37 of Set 12 | buraydah
# Processing Record 38 of Set 12 | ulcinj
# Processing Record 39 of Set 12 | timra
# Processing Record 40 of Set 12 | kyakhta
# Processing Record 41 of Set 12 | sao paulo de olivenca
# Processing Record 42 of Set 12 | gimli
# Processing Record 43 of Set 12 | correntina
# Processing Record 44 of Set 12 | ghanzi
# Processing Record 45 of Set 12 | nancha
# Processing Record 46 of Set 12 | fallon
# Processing Record 47 of Set 12 | oneonta
# Processing Record 48 of Set 12 | salalah
# Processing Record 49 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 12 | fremont
# Processing Record 1 of Set 13 | saint-augustin
# Processing Record 2 of Set 13 | mali
# Processing Record 3 of Set 13 | willowmore
# Processing Record 4 of Set 13 | bereda
# Processing Record 5 of Set 13 | mnogovershinnyy
# Processing Record 6 of Set 13 | huarmey
# Processing Record 7 of Set 13 | east stroudsburg
# Processing Record 8 of Set 13 | rapina
# Processing Record 9 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 13 | lodja
# Processing Record 11 of Set 13 | kerema
# Processing Record 12 of Set 13 | manggar
# Processing Record 13 of Set 13 | north bay
# Processing Record 14 of Set 13 | yithion
# City not found. Skipping...
# Processing Record 15 of Set 13 | novoseleznevo
# Processing Record 16 of Set 13 | ternate
# Processing Record 17 of Set 13 | fereydunshahr
# Processing Record 18 of Set 13 | owosso
# Processing Record 19 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 13 | pauini
# Processing Record 21 of Set 13 | wajima
# Processing Record 22 of Set 13 | necochea
# Processing Record 23 of Set 13 | ravar
# Processing Record 24 of Set 13 | kushmurun
# Processing Record 25 of Set 13 | cuauhtemoc
# Processing Record 26 of Set 13 | yei
# Processing Record 27 of Set 13 | itarema
# Processing Record 28 of Set 13 | luceville
# City not found. Skipping...
# Processing Record 29 of Set 13 | divinopolis
# Processing Record 30 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 13 | yueyang
# Processing Record 32 of Set 13 | olinda
# Processing Record 33 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 13 | saskylakh
# Processing Record 35 of Set 13 | yeppoon
# Processing Record 36 of Set 13 | dymer
# Processing Record 37 of Set 13 | sovetskiy
# Processing Record 38 of Set 13 | beringovskiy
# Processing Record 39 of Set 13 | sinnamary
# Processing Record 40 of Set 13 | tautira
# Processing Record 41 of Set 13 | bandarbeyla
# Processing Record 42 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 13 | nizhniy tsasuchey
# Processing Record 44 of Set 13 | viseu
# Processing Record 45 of Set 13 | tura
# Processing Record 46 of Set 13 | udomlya
# Processing Record 47 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 13 | chapais
# Processing Record 49 of Set 13 | durban
# Processing Record 50 of Set 13 | alta gracia
# Processing Record 1 of Set 14 | erenhot
# Processing Record 2 of Set 14 | medea
# Processing Record 3 of Set 14 | riohacha
# Processing Record 4 of Set 14 | methoni
# Processing Record 5 of Set 14 | saint anthony
# Processing Record 6 of Set 14 | camargo
# Processing Record 7 of Set 14 | nacala
# Processing Record 8 of Set 14 | sisimiut
# Processing Record 9 of Set 14 | emba
# Processing Record 10 of Set 14 | eldoret
# Processing Record 11 of Set 14 | lorengau
# Processing Record 12 of Set 14 | zurrieq
# Processing Record 13 of Set 14 | svetlograd
# Processing Record 14 of Set 14 | havelock
# Processing Record 15 of Set 14 | grants pass
# Processing Record 16 of Set 14 | calvinia
# Processing Record 17 of Set 14 | lazurne
# Processing Record 18 of Set 14 | margate
# Processing Record 19 of Set 14 | urusha
# Processing Record 20 of Set 14 | waddan
# Processing Record 21 of Set 14 | raga
# Processing Record 22 of Set 14 | la ronge
# Processing Record 23 of Set 14 | rosarito
# Processing Record 24 of Set 14 | lakatoro
# Processing Record 25 of Set 14 | hit
# Processing Record 26 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 14 | parakai
# Processing Record 28 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 14 | komsomolskiy
# Processing Record 30 of Set 14 | luau
# Processing Record 31 of Set 14 | tsiroanomandidy
# Processing Record 32 of Set 14 | ngorongoro
# Processing Record 33 of Set 14 | bajil
# Processing Record 34 of Set 14 | aranos
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | san vicente
# Processing Record 37 of Set 14 | songea
# Processing Record 38 of Set 14 | montijo
# Processing Record 39 of Set 14 | marquette
# Processing Record 40 of Set 14 | aksu
# Processing Record 41 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 14 | edgewater
# Processing Record 43 of Set 14 | mitsamiouli
# Processing Record 44 of Set 14 | keokuk
# Processing Record 45 of Set 14 | saint andrews
# Processing Record 46 of Set 14 | tunceli
# Processing Record 47 of Set 14 | planos
# Processing Record 48 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 14 | onega
# Processing Record 50 of Set 14 | vilyuysk
# Processing Record 1 of Set 15 | ginir
# Processing Record 2 of Set 15 | yerofey pavlovich
# Processing Record 3 of Set 15 | nishihara
# Processing Record 4 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 15 | asfi
# Processing Record 6 of Set 15 | jasper
# Processing Record 7 of Set 15 | solwezi
# Processing Record 8 of Set 15 | loviisa
# Processing Record 9 of Set 15 | kieta
# Processing Record 10 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 11 of Set 15 | evensk
# Processing Record 12 of Set 15 | male
# Processing Record 13 of Set 15 | zheleznodorozhnyy
# Processing Record 14 of Set 15 | nicoya
# Processing Record 15 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 15 | uige
# Processing Record 17 of Set 15 | pingliang
# Processing Record 18 of Set 15 | omaruru
# Processing Record 19 of Set 15 | samfya
# Processing Record 20 of Set 15 | gao
# Processing Record 21 of Set 15 | ketchikan
# Processing Record 22 of Set 15 | husavik
# Processing Record 23 of Set 15 | verkhnyaya inta
# Processing Record 24 of Set 15 | tongzi
# Processing Record 25 of Set 15 | tramandai
# Processing Record 26 of Set 15 | fez
# Processing Record 27 of Set 15 | loukhi
# Processing Record 28 of Set 15 | puri
# Processing Record 29 of Set 15 | awjilah
# Processing Record 30 of Set 15 | lubao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# Change column order
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country                 Date    Lat     Lng  \
# 0             Vila Velha      BR  2020-08-30 16:24:28 -20.33  -40.29
# 1            East London      ZA  2020-08-30 16:32:02 -33.02   27.91
# 2               Klaksvik      FO  2020-08-30 16:32:03  62.23   -6.59
# 3  Imeni Poliny Osipenko      RU  2020-08-30 16:24:29  52.42  136.49
# 4                Rikitea      PF  2020-08-30 16:32:03 -23.12 -134.97
# 5                 Bethel      US  2020-08-30 16:32:03  41.37  -73.41
# 6             Chokurdakh      RU  2020-08-30 16:32:03  70.63  147.92
# 7                Zambezi      ZM  2020-08-30 16:24:29 -13.54   23.10
# 8                  Belen      TR  2020-08-30 16:24:29  36.49   36.22
# 9               Waingapu      ID  2020-08-30 16:24:30  -9.66  120.26
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     80.01        88          40        9.17    scattered clouds
# 1     55.40        47          31       14.99    scattered clouds
# 2     51.80        93          95        8.05     overcast clouds
# 3     46.33        84           1        3.87           clear sky
# 4     69.31        83          65       19.89          light rain
# 5     72.00        50          19        1.01          few clouds
# 6     41.90        80         100        6.85     overcast clouds
# 7     78.28        48          73        1.01       broken clouds
# 8     91.40        46           0       12.75           clear sky
# 9     74.57        79          78       12.53       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
